# %%
import yfinance as yf
from config import get_config_dict
import datetime as dt
import sys
from pathlib import Path
from loguru import logger
from tqdm import tqdm
import pandas as pd

from config import get_config_dict
from pipeline import Stock, Etl, market_scraper, Preprocess
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
handler = Etl()
#handler.extract_stock_data()
handler.extract_sp_500()
f_data, m_data = handler.load_stock_data()
index_data = handler.load_index_data()
print(f_data.shape, m_data.shape, index_data.shape)
preprocessor = Preprocess(f_data, m_data, index_data)
df = preprocessor.feature_engineering()
# Out:
# 2023-08-19 17:19:45.710 | INFO     | pipeline.etl:extract_sp_500:34 - starting sp500 data extraction process
# 2023-08-19 17:19:46.899 | INFO     | pipeline.etl:load_stock_data:73 - loading stock data
# 2023-08-19 17:19:46.907 | INFO     | pipeline.stock:_initialize_stock:67 - repository for A exists (2023-05-23)
# 2023-08-19 17:19:46.923 | INFO     | pipeline.stock:_initialize_stock:67 - repository for AABA exists (2017-04-18)
# 2023-08-19 17:19:46.937 | INFO     | pipeline.stock:_initialize_stock:67 - repository for AAL exists (2023-07-20)
# (197, 33) (12693, 4) (4687, 4)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/envs/fin/lib/python3.11/site-packages/pandas/core/indexes/base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~/opt/anaconda3/envs/fin/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/envs/fin/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 8
#       6 print(f_data.shape, m_data.shape, index_data.shape)
#       7 preprocessor = Preprocess(f_data, m_data, index_data)
# ----> 8 df = preprocessor.feature_engineering()
#
# File ~/Desktop/Projects/stockselector/pipeline/preprocess.py:21, in Preprocess.feature_engineering(self)
#      18 mkt_df = self.market_data.copy()
#      20 #master = self._add_financial_ratios(fin_df)
# ---> 21 master = self._add_market_ratios(mkt_df)
#      22 #master = self._add_growth_ratios(df)
#      24 return master[['tic', 'datadate', 'saleq', 'invtq', 'rev_g4q', 'inv_avg']]
#
# File ~/Desktop/Projects/stockselector/pipeline/preprocess.py:81, in Preprocess._add_market_ratios(self, df)
#      79 def _add_market_ratios(self, df):
# ---> 81     df = get_rsi(df, 14)
#      83     return df
#
# File ~/Desktop/Projects/stockselector/pipeline/preprocess.py:91, in get_rsi(close, lookback)
#      89 down = []
#      90 for i in range(len(ret)):
# ---> 91     if ret[i] < 0:
#      92         up.append(0)
#      93         down.append(ret[i])
#
# File ~/opt/anaconda3/envs/fin/lib/python3.11/site-packages/pandas/core/frame.py:3760, in DataFrame.__getitem__(self, key)
#    3758 if self.columns.nlevels > 1:
#    3759     return self._getitem_multilevel(key)
# -> 3760 indexer = self.columns.get_loc(key)
#    3761 if is_integer(indexer):
#    3762     indexer = [indexer]
#
# File ~/opt/anaconda3/envs/fin/lib/python3.11/site-packages/pandas/core/indexes/base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 0

# %%
import pandas as pd
import numpy as np
from utils import list_sp500_stocks

df =  pd.read_csv(
    '../data/1_work_data/SP500.csv',
    sep=';',
    usecols=['Symbol', 'Sector']
)


active_stocks = list_sp500_stocks()
active_stocks
# Out:
#     Symbol                  Sector
# 0      MMM             Industrials
# 1      AOS             Industrials
# 2      ABT             Health Care
# 3     ABBV             Health Care
# 4      ACN  Information Technology
# ..     ...                     ...
# 498    XYL             Industrials
# 499    YUM  Consumer Discretionary
# 500   ZBRA  Information Technology
# 501    ZBH             Health Care
# 502    ZTS             Health Care
#
# [503 rows x 2 columns]

# %%
all_df = pd.concat([df, active_stocks])
all_df = all_df.drop_duplicates(subset=['Symbol']).reset_index()
all_df['Status'] = np.where(all_df['Symbol'].isin(active_stocks['Symbol'].values.tolist()), True, False)
all_df.to_csv()

# %%
all_df
# Out:
#      index Symbol                  Sector  Status
# 0        0      A             Health Care    True
# 1        1   AABA              Financials   False
# 2        2    AAL             Industrials    True
# 3        3    AAP  Consumer Discretionary   False
# 4        4   AAPL  Information Technology    True
# ..     ...    ...                     ...     ...
# 929    420   SOLV             Health Care    True
# 930    429   SMCI  Information Technology    True
# 931    457   UBER             Industrials    True
# 932    468   VLTO             Industrials    True
# 933    476    VST               Utilities    True
#
# [934 rows x 4 columns]
